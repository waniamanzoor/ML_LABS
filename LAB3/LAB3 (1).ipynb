# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df=pd.read_csv("Student_Marks.csv")
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
df.isna()
# Out:
#     number_courses  time_study  Marks
# 0            False       False  False
# 1            False       False  False
# 2            False       False  False
# 3            False       False  False
# 4            False       False  False
# ..             ...         ...    ...
# 95           False       False  False
# 96           False       False  False
# 97           False       False  False
# 98           False       False  False
# 99           False       False  False
#
# [100 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.isna().sum()
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64

# %%
X = df[['number_courses', 'time_study']].values  # Features (2D)
y = df['Marks'].values.reshape(-1, 1)  # Target (reshape to column vector)

# %%
X
# Out:
# array([[3.   , 4.508],
#        [4.   , 0.096],
#        [4.   , 3.133],
#        [6.   , 7.909],
#        [8.   , 7.811],
#        [6.   , 3.211],
#        [3.   , 6.063],
#        [5.   , 3.413],
#        [4.   , 4.41 ],
#        [3.   , 6.173],
#        [3.   , 7.353],
#        [7.   , 0.423],
#        [7.   , 4.218],
#        [3.   , 4.274],
#        [3.   , 2.908],
#        [4.   , 4.26 ],
#        [5.   , 5.719],
#        [8.   , 6.08 ],
#        [6.   , 7.711],
#        [8.   , 3.977],
#        [4.   , 4.733],
#        [6.   , 6.126],
#        [5.   , 2.051],
#        [7.   , 4.875],
#        [4.   , 3.635],
#        [3.   , 1.407],
#        [7.   , 0.508],
#        [8.   , 4.378],
#        [5.   , 0.156],
#        [4.   , 1.299],
#        [8.   , 3.864],
#        [3.   , 1.923],
#        [8.   , 0.932],
#        [6.   , 6.594],
#        [3.   , 4.083],
#        [3.   , 7.543],
#        [4.   , 2.966],
#        [6.   , 7.283],
#        [7.   , 6.533],
#        [6.   , 7.775],
#        [4.   , 0.14 ],
#        [6.   , 2.754],
#        [6.   , 3.591],
#        [5.   , 1.557],
#        [4.   , 1.954],
#        [3.   , 2.061],
#        [4.   , 3.797],
#        [4.   , 4.779],
#        [3.   , 5.635],
#        [5.   , 3.913],
#        [6.   , 6.703],
#        [6.   , 4.13 ],
#        [4.   , 0.771],
#        [7.   , 6.049],
#        [8.   , 7.591],
#        [7.   , 2.913],
#        [8.   , 7.641],
#        [7.   , 7.649],
#        [3.   , 6.198],
#        [8.   , 7.468],
#        [6.   , 0.376],
#        [4.   , 2.438],
#        [6.   , 3.606],
#        [3.   , 4.869],
#        [7.   , 0.13 ],
#        [6.   , 2.142],
#        [4.   , 5.473],
#        [3.   , 0.55 ],
#        [4.   , 1.395],
#        [6.   , 3.948],
#        [4.   , 3.736],
#        [5.   , 2.518],
#        [3.   , 4.633],
#        [3.   , 1.629],
#        [4.   , 6.954],
#        [3.   , 0.803],
#        [5.   , 6.379],
#        [8.   , 5.985],
#        [7.   , 7.451],
#        [3.   , 0.805],
#        [7.   , 7.957],
#        [8.   , 2.262],
#        [4.   , 7.41 ],
#        [5.   , 3.197],
#        [8.   , 1.982],
#        [8.   , 6.201],
#        [7.   , 4.067],
#        [3.   , 1.033],
#        [5.   , 1.803],
#        [7.   , 6.376],
#        [7.   , 4.182],
#        [8.   , 2.73 ],
#        [4.   , 5.027],
#        [8.   , 6.471],
#        [8.   , 3.919],
#        [6.   , 3.561],
#        [3.   , 0.301],
#        [4.   , 7.163],
#        [7.   , 0.309],
#        [3.   , 6.335]])

# %%
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# %%
X
# Out:
# array([[-1.27897041,  0.18248894],
#        [-0.72046805, -1.68619512],
#        [-0.72046805, -0.39988653],
#        [ 0.39653668,  1.6229682 ],
#        [ 1.5135414 ,  1.58146071],
#        [ 0.39653668, -0.36684996],
#        [-1.27897041,  0.84110266],
#        [-0.16196569, -0.28129371],
#        [-0.72046805,  0.14098145],
#        [-1.27897041,  0.8876927 ],
#        [-1.27897041,  1.38747674],
#        [ 0.95503904, -1.54769564],
#        [ 0.95503904,  0.05966066],
#        [-1.27897041,  0.08337923],
#        [-1.27897041, -0.49518433],
#        [-0.72046805,  0.07744958],
#        [-0.16196569,  0.6954029 ],
#        [ 1.5135414 ,  0.84830294],
#        [ 0.39653668,  1.53910613],
#        [ 1.5135414 , -0.04241388],
#        [-0.72046805,  0.27778675],
#        [ 0.39653668,  0.86778604],
#        [-0.16196569, -0.85816308],
#        [ 0.95503904,  0.33793025],
#        [-0.72046805, -0.18726654],
#        [-1.27897041, -1.13092658],
#        [ 0.95503904, -1.51169425],
#        [ 1.5135414 ,  0.12742799],
#        [-0.16196569, -1.66078237],
#        [-0.72046805, -1.17666952],
#        [ 1.5135414 , -0.09027455],
#        [-1.27897041, -0.91237695],
#        [ 1.5135414 , -1.33211083],
#        [ 0.39653668,  1.06600548],
#        [-1.27897041,  0.00248198],
#        [-1.27897041,  1.46795044],
#        [-0.72046805, -0.47061868],
#        [ 0.39653668,  1.35782853],
#        [ 0.95503904,  1.04016918],
#        [ 0.39653668,  1.56621307],
#        [-0.72046805, -1.6675591 ],
#        [ 0.39653668, -0.56041039],
#        [ 0.39653668, -0.20590255],
#        [-0.16196569, -1.06739471],
#        [-0.72046805, -0.89924703],
#        [-1.27897041, -0.85392763],
#        [-0.72046805, -0.11865212],
#        [-0.72046805,  0.29726985],
#        [-1.27897041,  0.65982506],
#        [-0.16196569, -0.06952081],
#        [ 0.39653668,  1.11217197],
#        [ 0.39653668,  0.02238863],
#        [-0.72046805, -1.40030171],
#        [ 0.95503904,  0.83517302],
#        [ 1.5135414 ,  1.48828064],
#        [ 0.95503904, -0.49306661],
#        [ 1.5135414 ,  1.50945793],
#        [ 0.95503904,  1.51284629],
#        [-1.27897041,  0.89828134],
#        [ 1.5135414 ,  1.43618451],
#        [ 0.39653668, -1.5676023 ],
#        [-0.72046805, -0.69425086],
#        [ 0.39653668, -0.19954937],
#        [-1.27897041,  0.33538898],
#        [ 0.95503904, -1.67179456],
#        [ 0.39653668, -0.81962042],
#        [-0.72046805,  0.59121064],
#        [-1.27897041, -1.49390533],
#        [-0.72046805, -1.13600913],
#        [ 0.39653668, -0.0546967 ],
#        [-0.72046805, -0.14448841],
#        [-0.16196569, -0.6603672 ],
#        [-1.27897041,  0.23543217],
#        [-1.27897041, -1.03689941],
#        [-0.72046805,  1.21848197],
#        [-1.27897041, -1.38674824],
#        [-0.16196569,  0.97494313],
#        [ 1.5135414 ,  0.80806609],
#        [ 0.95503904,  1.42898423],
#        [-1.27897041, -1.38590115],
#        [ 0.95503904,  1.6432984 ],
#        [ 1.5135414 , -0.76879492],
#        [-0.72046805,  1.41161885],
#        [-0.16196569, -0.3727796 ],
#        [ 1.5135414 , -0.88738774],
#        [ 1.5135414 ,  0.89955198],
#        [ 0.95503904, -0.00429475],
#        [-1.27897041, -1.28933271],
#        [-0.16196569, -0.96320244],
#        [ 0.95503904,  0.97367249],
#        [ 0.95503904,  0.04441301],
#        [ 1.5135414 , -0.57057549],
#        [-0.72046805,  0.40230921],
#        [ 1.5135414 ,  1.01390934],
#        [ 1.5135414 , -0.06697953],
#        [ 0.39653668, -0.21860893],
#        [-1.27897041, -1.59936823],
#        [-0.72046805,  1.30700304],
#        [ 0.95503904, -1.59597986],
#        [-1.27897041,  0.95630712]])

# %%
# Add bias term (column of ones)
m = len(y)  # Number of training examples
X_b = np.c_[np.ones((m, 1)), X]  # Add x0 = 1 for theta_0 (bias term)

# %%
# Initialize parameters (theta values)
theta = np.zeros((3, 1))  # [theta_0, theta_1, theta_2]
alpha = 0.01  # Learning rate
epochs = 1000  # Number of iterations

# %%
theta
# Out:
# array([[0.],
#        [0.],
#        [0.]])

# %% [markdown]
# #  Cost Function (Mean Squared Error)

# %%
def compute_cost(X, y, theta):
    m = len(y)
    predictions = X.dot(theta)
    cost = (1 / (2 * m)) * np.sum((predictions - y) ** 2)
    return cost

# %% [markdown]
# #  Gradient Descent Algorithm

# %%
def gradient_descent(X, y, theta, alpha, epochs):
    m = len(y)
    cost_history = []  # Store cost values for plotting

    for epoch in range(epochs):
        predictions = X.dot(theta)  # Compute hypothesis
        errors = predictions - y  # Compute errors
        gradients = (1 / m) * X.T.dot(errors)  # Compute gradients
        theta -= alpha * gradients  # Update theta

        cost = compute_cost(X, y, theta)  # Compute cost after update
        cost_history.append(cost)  # Store cost

        # Print cost every 100 iterations
        if epoch % 100 == 0:
            print(f"Epoch {epoch}: Cost = {cost}")

    return theta, cost_history

# %%
theta_optimal, cost_history = gradient_descent(X_b, y, theta, alpha, epochs)
# Out:
# Epoch 0: Cost = 391.6277034298356
# Epoch 100: Cost = 55.4485760603202
# Epoch 200: Cost = 12.610411023009835
# Epoch 300: Cost = 6.957968969428677
# Epoch 400: Cost = 6.186472131173093
# Epoch 500: Cost = 6.077417626212519
# Epoch 600: Cost = 6.061404647815628
# Epoch 700: Cost = 6.058953176146259
# Epoch 800: Cost = 6.058560775907576
# Epoch 900: Cost = 6.058495074248158

# %%
print("Optimized Theta Values:", theta_optimal.flatten())
# Out:
# Optimized Theta Values: [24.41663586  3.33914903 12.74591921]

# %%
plt.plot(range(epochs), cost_history, color='blue')
plt.xlabel("Iterations")
plt.ylabel("Cost (MSE)")
plt.title("Cost Function Convergence")
plt.show()
